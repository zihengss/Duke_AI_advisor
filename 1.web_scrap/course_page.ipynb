# %%
import requests
from bs4 import BeautifulSoup

def fetch_course_page(url):
    # Send a request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the content of the webpage
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the specific <div> with the given class
        course_info = soup.find('div', class_="col-sm-8 bs-region bs-region--left")
        if not course_info:
            return None
        return course_info.text
    else:
        return None

import os

def save_string_to_file(text, filename):
    """
    Save a string to a text file, creating the folder if it doesn't exist.
    
    :param text: The string to save
    :param filename: The name of the file, including its path
    """
    # Extract the directory from the filename
    folder = os.path.dirname(filename)
    
    # Create the folder if it doesn't exist
    if folder and not os.path.exists(folder):
        os.makedirs(folder)
    
    # Write the text to the file
    with open(filename, 'w') as file:
        file.write(text)

# %%
def url2txt(url):
    course_info_string = fetch_course_page(url)
    if not course_info_string:
        print(f"{url} cannot find content") 
    else:
        # print(len(course_info_string))
        save_string_to_file(course_info_string, '../data/rag_data/course/'+url.split('/')[-1]+'.txt')

# %%
import pandas as pd


url = 'https://cs.duke.edu/course-catalog'
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the content of the webpage
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the specific <div> with the given class
    course_info = soup.find('table', class_="tablesaw tablesaw-stack table table-hover views-table views-view-table cols-3")
    # Extract headers
    headers = [header.text.strip() for header in course_info.find_all('th')]

    # Extract rows
    rows = course_info.find_all('tr')[1:]  # Skip the header row
    data = []

    for row in rows:
        cells = row.find_all('td')
        cell_data = []
        for cell in cells:
            # Check if there is a link in the cell
            link = cell.find('a')
            if link:
                cell_text = cell.text.strip()
                cell_href = link.get('href', '')
                cell_data.append({'text': cell_text, 'href': cell_href})
            else:
                cell_data.append({'text': cell.text.strip(), 'href': ''})
        data.append(cell_data)
            # Create a DataFrame
    df = pd.DataFrame(data, columns=headers)

# %%
urls = ['https://cs.duke.edu'+df['Title'][i]['href'] for i in range(len(df['Title']))]
print(urls)
# Out:
# ['https://cs.duke.edu/courses/principles-computer-science', 'https://cs.duke.edu/courses/first-year-seminar-0', 'https://cs.duke.edu/courses/technical-and-social-analysis-information-and-internet-0', 'https://cs.duke.edu/courses/history-computing-cryptography-and-robotic-devices', 'https://cs.duke.edu/courses/programming-and-problem-solving-0', 'https://cs.duke.edu/courses/programming-and-problem-solving-1', 'https://cs.duke.edu/courses/introduction-computer-science-0', 'https://cs.duke.edu/courses/introduction-computer-science-1', 'https://cs.duke.edu/courses/interdisciplinary-introduction-computer-science', 'https://cs.duke.edu/courses/computing-and-brain', 'https://cs.duke.edu/courses/information-society-culture-bass-connections-gateway', 'https://cs.duke.edu/courses/introduction-digital-feminism', 'https://cs.duke.edu/courses/foundations-data-science-0', 'https://cs.duke.edu/courses/topics-computer-science-2', 'https://cs.duke.edu/courses/duke-administered-study-abroad-special-topics-computer-science', 'https://cs.duke.edu/courses/focus-program-topics-computer-science', 'https://cs.duke.edu/courses/topics-computer-science-3', 'https://cs.duke.edu/courses/introduction-cyber-policy', 'https://cs.duke.edu/courses/data-structures-and-algorithms-0', 'https://cs.duke.edu/courses/introduction-mobile-application-development-ios', 'https://cs.duke.edu/courses/introduction-computer-systems', 'https://cs.duke.edu/courses/everything-data-0', 'https://cs.duke.edu/courses/user-research-methods-human-centered-computing', 'https://cs.duke.edu/courses/discrete-math-computer-science-1', 'https://cs.duke.edu/courses/discrete-mathematics-and-proofs', 'https://cs.duke.edu/courses/race-gender-class-computing', 'https://cs.duke.edu/courses/programming-interview-skills-and-practice-0', 'https://cs.duke.edu/courses/human-flourishing-digital-age', 'https://cs.duke.edu/courses/computer-science-education-research', 'https://cs.duke.edu/courses/computer-architecture-1', 'https://cs.duke.edu/courses/introduction-computational-genomics', 'https://cs.duke.edu/courses/logic-and-its-applications', 'https://cs.duke.edu/courses/topics-computer-science', 'https://cs.duke.edu/courses/duke-administered-study-abroad-advanced-special-topics-computer-science', 'https://cs.duke.edu/courses/topics-computer-science-4', 'https://cs.duke.edu/courses/topics-computer-science-0', 'https://cs.duke.edu/courses/software-design-and-implementation', 'https://cs.duke.edu/courses/advanced-software-design-and-implementation', 'https://cs.duke.edu/courses/introduction-operating-systems-1', 'https://cs.duke.edu/courses/introduction-database-systems-1', 'https://cs.duke.edu/courses/introduction-database-systems-2', 'https://cs.duke.edu/courses/numerical-data-analysis-and-methods', 'https://cs.duke.edu/courses/graph-analysis-matrix-computation', 'https://cs.duke.edu/courses/computational-microeconomics-0', 'https://cs.duke.edu/courses/introduction-design-and-analysis-algorithms-0', 'https://cs.duke.edu/courses/algorithms-real-world', 'https://cs.duke.edu/courses/mathematical-foundations-computer-science-0', 'https://cs.duke.edu/courses/technical-and-social-analysis-information-and-internet-1', 'https://cs.duke.edu/courses/computer-graphics', 'https://cs.duke.edu/courses/graphics-software-architecture', 'https://cs.duke.edu/courses/digital-systems-0', 'https://cs.duke.edu/courses/introduction-computer-security', 'https://cs.duke.edu/courses/foundations-blockchains-0', 'https://cs.duke.edu/courses/computer-network-architecture-0', 'https://cs.duke.edu/courses/introduction-computational-imaging', 'https://cs.duke.edu/courses/introduction-artificial-intelligence', 'https://cs.duke.edu/courses/elements-machine-learning-0', 'https://cs.duke.edu/courses/computational-approaches-human-language', 'https://cs.duke.edu/courses/topics-computer-science-1', 'https://cs.duke.edu/courses/duke-administered-study-abroad-advanced-special-topics-computer-science-0', 'https://cs.duke.edu/courses/independ ...

# %%
print(len(urls))
# Out:
# 124

# %%
from tqdm import tqdm


for url in tqdm(urls, desc="Processing URLs"):
    url2txt(url)
# Out:
# Processing URLs: 100%|██████████| 124/124 [02:22<00:00,  1.15s/it]

# %%
import os

# Define the directory path
directory = '/Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course'

# Iterate over all .txt files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(directory, filename)
        
        # Read the file and process the lines
        with open(filepath, 'r') as file:
            lines = file.readlines()

        # Remove empty lines and strip leading whitespace
        cleaned_lines = [line.lstrip() for line in lines if line.strip()]

        # Check if the file contains "No Overview" and delete it if so
        if any("No Overview" in line for line in cleaned_lines):
            os.remove(filepath)
            print(f"Deleted file: {filepath} (contains 'No Overview')")
        else:
            # Write the cleaned lines back to the file
            with open(filepath, 'w') as file:
                file.writelines(cleaned_lines)
            print(f"Processed file: {filepath}")
# Out:
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/algorithms-real-world.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/modern-optimization-statistical-learning.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/geometric-algorithms.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/high-dimensional-statistics-and-machine-learning.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topics-computer-science-3.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topics-computer-science-2.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/delivering-software-concept-client-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/digital-systems-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/artificial-intelligence-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-science-education-research.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/foundations-blockchains.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-design-and-analysis-algorithms-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/technical-and-social-analysis-information-and-internet-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-network-architecture-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topics-computer-science-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topics-computer-science-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topological-data-analysis.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/technical-and-social-analysis-information-and-internet-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/duke-administered-study-abroad-advanced-special-topics-computer-science-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topics-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-mobile-application-development-ios.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/first-year-seminar-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/mobile-app-development-programmers-and-entrepreneurs-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/topics-computer-science-4.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-cyber-policy.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/duke-administered-study-abroad-advanced-special-topics-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/theory-and-algorithms-machine-learning.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/data-science-competition.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/logic-and-its-applications.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/numerical-analysis-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/full-stack-iot-systems-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computational-sequence-biology.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-operating-systems-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-graduate-students-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/data-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/research-independent-study.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/design-and-analysis-algorithms.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/information-society-culture-bass-connections-gateway.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/interdisciplinary-introduction-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/graphical-models-biological-data.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/principles-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/focus-program-topics-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/database-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/dynamics-complex-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-database-systems-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/cryptography.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/numerical-data-analysis-and-methods.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-computer-architecture-i.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computational-complexity.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-artificial-intelligence.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-topics-nonlinear-and-complex-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-architecture-and-hardware-acceleration.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-digital-feminism.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/graph-algorithms.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-database-systems-2.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computational-microeconomics-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/randomized-algorithms.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/data-structures-and-algorithms-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/operating-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-science-masters-program-career-preparation-and-development.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-natural-language-processing.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-architecture-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/programming-interview-skills-and-practice-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/high-resolution-cryo-electron-microscopy-image-analysis.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-topics-computer-science-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/internship.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/wireless-networking-and-mobile-computing-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/fault-tolerant-and-testable-computer-systems-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-high-dimensional-data-analysis.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/probabilistic-machine-learning-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/applications-data-and-materials-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/user-research-methods-human-centered-computing.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/everything-data-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/edge-computing.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/foundations-data-science-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-computer-networks.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/probability-electrical-and-computer-engineers-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/history-computing-cryptography-and-robotic-devices.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/discrete-mathematics-and-proofs.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-mathematical-logic.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/graph-analysis-matrix-computation-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computing-and-brain.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-deep-learning-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/elements-machine-learning-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computational-imaging.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-computer-architecture-ii.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computer-science-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/graph-analysis-matrix-computation.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/foundations-blockchains-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/duke-administered-study-abroad-special-topics-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-topics-deep-learning.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computer-science-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/mathematical-foundations-computer-science-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/human-centered-computing.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/algorithmic-game-theory.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computational-complexity-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/graphics-software-architecture.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computational-genomics.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computational-approaches-human-language.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computer-security.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/algorithms-structural-biology-and-biophysics.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computer-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/approximation-algorithms.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-algorithms.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/secure-software-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/programming-interview-skills-and-practice.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/distributed-systems.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-software-design-and-implementation.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/programming-and-problem-solving-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-security-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/independent-study.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/race-gender-class-computing.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/compiler-construction-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/deep-learning-fundamentals.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/software-design-and-implementation.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/discrete-math-computer-science-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/programming-and-problem-solving-1.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/human-centered-security-and-privacy.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/advanced-topics-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/introduction-computer-vision.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/computer-graphics.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/research-independent-study-0.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/special-readings-computer-science.txt
# Processed file: /Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course/human-flourishing-digital-age.txt

# %%
print(f'now the folder have total {len(os.listdir(directory))} files')
# Out:
# now the folder have total 124 files

# %%
import os

# Define the directory path
directory = '/Users/zihengs/Desktop/Duke_AI_advisor/data/rag_data/course'

# Initialize counters for total word count and file count
total_word_count = 0
file_count = 0

# Iterate over all .txt files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(directory, filename)
        
        # Read the file and count the words
        with open(filepath, 'r') as file:
            lines = file.readlines()
            word_count = sum(len(line.split()) for line in lines)  # Count words in each line
        
        # Update counters
        total_word_count += word_count
        file_count += 1
        
        print(f"{filename} has {word_count} words")

# Calculate and print the average word count
if file_count > 0:
    average_word_count = total_word_count / file_count
    print(f"Average word count per file: {average_word_count:.2f}")
else:
    print("No .txt files found in the directory.")
# Out:
# algorithms-real-world.txt has 86 words
# modern-optimization-statistical-learning.txt has 110 words
# geometric-algorithms.txt has 42 words
# high-dimensional-statistics-and-machine-learning.txt has 72 words
# topics-computer-science-3.txt has 18 words
# topics-computer-science-2.txt has 2 words
# delivering-software-concept-client-0.txt has 67 words
# digital-systems-0.txt has 72 words
# artificial-intelligence-1.txt has 38 words
# computer-science-education-research.txt has 44 words
# foundations-blockchains.txt has 118 words
# introduction-design-and-analysis-algorithms-0.txt has 41 words
# technical-and-social-analysis-information-and-internet-1.txt has 99 words
# computer-network-architecture-0.txt has 109 words
# topics-computer-science-0.txt has 8 words
# topics-computer-science-1.txt has 36 words
# topological-data-analysis.txt has 39 words
# technical-and-social-analysis-information-and-internet-0.txt has 67 words
# duke-administered-study-abroad-advanced-special-topics-computer-science-0.txt has 6 words
# topics-computer-science.txt has 62 words
# introduction-mobile-application-development-ios.txt has 95 words
# first-year-seminar-0.txt has 20 words
# mobile-app-development-programmers-and-entrepreneurs-0.txt has 104 words
# topics-computer-science-4.txt has 7 words
# introduction-cyber-policy.txt has 95 words
# duke-administered-study-abroad-advanced-special-topics-computer-science.txt has 6 words
# theory-and-algorithms-machine-learning.txt has 58 words
# data-science-competition.txt has 154 words
# logic-and-its-applications.txt has 44 words
# numerical-analysis-0.txt has 38 words
# full-stack-iot-systems-0.txt has 98 words
# computational-sequence-biology.txt has 91 words
# introduction-operating-systems-1.txt has 69 words
# introduction-graduate-students-computer-science.txt has 79 words
# data-science.txt has 116 words
# research-independent-study.txt has 54 words
# design-and-analysis-algorithms.txt has 33 words
# information-society-culture-bass-connections-gateway.txt has 88 words
# interdisciplinary-introduction-computer-science.txt has 63 words
# graphical-models-biological-data.txt has 66 words
# principles-computer-science.txt has 16 words
# focus-program-topics-computer-science.txt has 24 words
# database-systems.txt has 91 words
# dynamics-complex-systems.txt has 94 words
# introduction-database-systems-1.txt has 80 words
# cryptography.txt has 59 words
# numerical-data-analysis-and-methods.txt has 7 words
# advanced-computer-architecture-i.txt has 45 words
# computational-complexity.txt has 43 words
# introduction-artificial-intelligence.txt has 47 words
# advanced-topics-nonlinear-and-complex-systems.txt has 77 words
# computer-architecture-and-hardware-acceleration.txt has 7 words
# introduction-digital-feminism.txt has 102 words
# graph-algorithms.txt has 81 words
# introduction-database-systems-2.txt has 80 words
# computational-microeconomics-0.txt has 50 words
# randomized-algorithms.txt has 64 words
# data-structures-and-algorithms-0.txt has 63 words
# operating-systems.txt has 35 words
# computer-science-masters-program-career-preparation-and-development.txt has 80 words
# introduction-natural-language-processing.txt has 107 words
# computer-architecture-1.txt has 39 words
# programming-interview-skills-and-practice-0.txt has 72 words
# high-resolution-cryo-electron-microscopy-image-analysis.txt has 89 words
# advanced-topics-computer-science-0.txt has 8 words
# internship.txt has 100 words
# wireless-networking-and-mobile-computing-0.txt has 54 words
# fault-tolerant-and-testable-computer-systems-0.txt has 37 words
# introduction-high-dimensional-data-analysis.txt has 51 words
# probabilistic-machine-learning-0.txt has 46 words
# applications-data-and-materials-science.txt has 67 words
# user-research-methods-human-centered-computing.txt has 97 words
# everything-data-0.txt has 63 words
# edge-computing.txt has 105 words
# foundations-data-science-0.txt has 87 words
# advanced-computer-networks.txt has 75 words
# probability-electrical-and-computer-engineers-0.txt has 50 words
# history-computing-cryptography-and-robotic-devices.txt has 98 words
# discrete-mathematics-and-proofs.txt has 71 words
# introduction-mathematical-logic.txt has 39 words
# graph-analysis-matrix-computation-0.txt has 85 words
# computing-and-brain.txt has 95 words
# introduction-deep-learning-0.txt has 116 words
# elements-machine-learning-0.txt has 74 words
# introduction-computational-imaging.txt has 86 words
# advanced-computer-architecture-ii.txt has 54 words
# introduction-computer-science-0.txt has 101 words
# graph-analysis-matrix-computation.txt has 88 words
# foundations-blockchains-0.txt has 122 words
# duke-administered-study-abroad-special-topics-computer-science.txt has 6 words
# advanced-topics-deep-learning.txt has 56 words
# introduction-computer-science-1.txt has 105 words
# mathematical-foundations-computer-science-0.txt has 43 words
# human-centered-computing.txt has 117 words
# algorithmic-game-theory.txt has 44 words
# computational-complexity-0.txt has 7 words
# graphics-software-architecture.txt has 119 words
# introduction-computational-genomics.txt has 85 words
# computational-approaches-human-language.txt has 7 words
# introduction-computer-security.txt has 80 words
# algorithms-structural-biology-and-biophysics.txt has 68 words
# introduction-computer-systems.txt has 90 words
# approximation-algorithms.txt has 29 words
# introduction-algorithms.txt has 23 words
# secure-software-systems.txt has 88 words
# programming-interview-skills-and-practice.txt has 63 words
# distributed-systems.txt has 59 words
# advanced-software-design-and-implementation.txt has 55 words
# programming-and-problem-solving-0.txt has 73 words
# computer-security-1.txt has 83 words
# independent-study.txt has 49 words
# race-gender-class-computing.txt has 45 words
# compiler-construction-0.txt has 100 words
# deep-learning-fundamentals.txt has 77 words
# software-design-and-implementation.txt has 54 words
# discrete-math-computer-science-1.txt has 63 words
# programming-and-problem-solving-1.txt has 49 words
# human-centered-security-and-privacy.txt has 100 words
# advanced-topics-computer-science.txt has 38 words
# introduction-computer-vision.txt has 41 words
# computer-graphics.txt has 64 words
# research-independent-study-0.txt has 20 words
# special-readings-computer-science.txt has 26 words
# human-flourishing-digital-age.txt has 120 words
# Average word count per file: 64.36
